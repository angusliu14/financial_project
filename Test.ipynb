# %%
import TS
from datetime import datetime 

TS.MA_Strategy("2498.TW", datetime(2021, 1, 1), datetime(2021, 7, 19), 0.1) 
TS.ROC_Strategy("2498.TW", datetime(2021, 1, 1), datetime(2021, 7, 19), 0.1)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ('買進日期=', '2021-02-23 ', '買進價格=', '29.05')
# ('賣出日期=', '2021-03-15 ', '賣出價格=', '28.70', '賠', '-0.52', '-1.78%')
# ('買進日期=', '2021-03-23 ', '買進價格=', '29.00')
# ('賣出日期=', '2021-05-13 ', '賣出價格=', '35.05', '賺', '5.85', '20.18%')
# ('買進日期=', '2021-06-03 ', '買進價格=', '37.25')
# ('賣出日期=', '2021-07-07 ', '賣出價格=', '38.15', '賺', '0.68', '1.82%')
# Cumulative Return: 6.013292283153534
# Number of Wins: 2
# Number of Losses: 1
# Final Price: 37.599998474121094
# Start Price: 31.399999618530273
# Every Transaction Return: [-0.5183922264099121, 5.853577990436554, 0.678106519126892]
# [*********************100%%**********************]  1 of 1 completed
# Cumulative Return: 0
# Number of Wins: 0
# Number of Losses: 0
# Final Price: 37.599998474121094
# Start Price: 31.399999618530273
# Every Transaction Return: []
# Cumulative Return: 0
# Number of Wins: 0
# Number of Losses: 0
# Final Price: 37.599998474121094
# ...
